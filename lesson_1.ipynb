# %% [markdown]
# Lesson #1

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
import matplotlib.pyplot as plt

y = [1,2,3,5,4]
x= [12,34,56,43,18]

plt.plot(x,y)
plt.ylabel('hoy')
plt.xlabel('mañana')
plt.title('espanish')
# Out:
# Text(0.5, 1.0, 'espanish')

# %% [markdown]
# ## Grahp 2

# %%
dias = ['lunes', 'martes', 'miercoles', 'jueves', 'viernes']
dinero = [76,32,54,76,32]
plt.bar(dias,dinero)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Graph 2

# %%
k = [12,54,675,12]
plt.pie(k)
# Out:
# ([<matplotlib.patches.Wedge at 0x25fcc7bf0a0>,
# ...
#  [Text(1.098621698323695, 0.05504874178726115, ''),
#   Text(1.0422667973577882, 0.3516815649497988, ''),
#   Text(-1.072201440773871, -0.24573170410517953, ''),
#   Text(1.098621698323695, -0.05504874178726188, '')])
